# %%
import json
import os
import pickle
from collections import OrderedDict
from tqdm import tqdm

# %%
import pickle

file_path = '/home/dhruv/Projects/VidSitu/vidsitu_data/clip-vit-large-patch14-336_11f/v_gwdClG0txYM_seg_130_140'

with open(file_path, 'rb') as f:
    loaded_object = pickle.load(f)
assert loaded_object['vid_feat'].size(0) ==11
# Use the loaded_object as needed

# %%
loaded_object['vid_feat'].shape
# Out:
# torch.Size([10, 768])

# %%
os.listdir(directory)
# Out:
# ['v_onbiOVpX0_w_seg_0_10',
#  'v_04BZh6E-Nck_seg_105_115',
#  'v_HZEaFYQecn8_seg_120_130',
#  'v_nSCUWDt53fw_seg_5_15',
#  'v_4CgNb8LRtng_seg_65_75',
#  'v_qqAzmt1d8kU_seg_15_25',
#  'v_hQIL99lP484_seg_55_65',
#  'v_ISs3m1aHZxY_seg_15_25',
#  'v_v2iOrjYQOHQ_seg_115_125',
#  'v_QBip3RFko4I_seg_0_10',
#  'v_nvCEzZ3P_x8_seg_115_125',
#  'v_LFVi_krq2PM_seg_140_150',
#  'v_YXt8RmeU_AA_seg_70_80',
#  'v_-rmALJkEprY_seg_115_125',
#  'v_BnPQSD0Pg4E_seg_70_80',
#  'v_7jrjZ5DIEzU_seg_25_35',
#  'v_WM3TedgbwIc_seg_65_75',
#  'v_EP74OZdI5d8_seg_25_35',
#  'v_tyyPSnHcthg_seg_50_60',
#  'v_cXlRo6pJ9ig_seg_35_45',
#  'v_5Svd15hqUfs_seg_45_55',
#  'v_UStNNBG5K0Y_seg_10_20',
#  'v_nDTVpRRoqcw_seg_15_25',
#  'v_b3z4_gJ5hGU_seg_80_90',
#  'v_km3VtR6mqmg_seg_85_95',
#  'v_GSSXEGoO53Y_seg_30_40',
#  'v_0W_kwmGYIS0_seg_100_110',
#  'v_LpDRf3h6OHw_seg_25_35',
#  'v_hEzyoeRuxYk_seg_25_35',
#  'v_DKqFCG3UTEs_seg_30_40',
#  'v_0gKYY9NCTvY_seg_250_260',
#  'v__GsQYT-btPA_seg_70_80',
# ...

# %%
train = './vidsitu_data/vidsitu_annotations/split_files/vseg_split_train_lb.json'
valid = './vidsitu_data/vidsitu_annotations/split_files/vseg_split_valid_lb.json'

# %%
train = './vidsitu_data/vidsitu_annotations/split_files/vseg_split_train_lb.json'
valid = './vidsitu_data/vidsitu_annotations/split_files/vseg_split_valid_lb.json'

with open(train, 'r') as f:
    train = json.load(f)

with open(valid, 'r') as f:
    valid = json.load(f)

# %%
'v_gwdClG0txYM_seg_130_140' in train
# Out:
# True

# %%
directory = '/home/dhruv/Projects/VidSitu/vidsitu_data/clip-vit-large-patch14-336_11f'

'/v_gwdClG0txYM_seg_130_140' in os.listdir(directory)
# Out:
# False

# %%
directory = '/home/dhruv/Projects/VidSitu/vidsitu_data/clip-vit-large-patch14-336_11f'
files = os.listdir(directory)
l14 = []
count_yes = 0
count_no = 0
for file in tqdm(files):
    with open(os.path.join(directory,file), 'rb') as f:
        try:
            data = pickle.load(f)
            count_yes += 1
        except:
            count_no += 1
            l14.append(file)
            continue
        #print(data.keys())
print('yes:', count_yes, 'no:', count_no)
# Out:
# ...
# 100%|██████████| 24875/24875 [42:27<00:00,  9.76it/s]
# yes: 24875 no: 0

# %%
l14
# Out:
# []

# %%
data = pickle.load(os.path.join(directory,file))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = pickle.load(os.path.join(directory,file))
#
# NameError: name 'pickle' is not defined

# %%
split = 'train'
root_dir = "/home/dhruv/Projects/VidSitu/vidsitu_data/"
split_dir = os.path.join(root_dir, "vidsitu_annotations/split_files")
split_name = os.path.join(split_dir, 'vseg_split_' + split + '_lb.json')
self.vids = json.load(open(split_name,'r'))

self.vid_trimmed_dir = os.path.join(root_dir, "vsitu_video_trimmed_dir")

anno_dir = os.path.join(root_dir, "vidsitu_annotations/vseg_ann_files")
anno_name = os.path.join(anno_dir, 'vsann_' + split + '_lb.json')
annos = json.load(open(anno_name,'r'))

# %%
b32 = []
directory = '/home/dhruv/Projects/VidSitu/vidsitu_data/clip_feat_vit-b32'
files = os.listdir(directory)
count_yes = 0
count_no = 0
for file in files:
    with open(os.path.join(directory,file), 'rb') as f:
        try:
            data = pickle.load(f)
            count_yes += 1
        except:
            count_no += 1
            b32.append(file)
            continue
        #print(data.keys())
print('yes:', count_yes, 'no:', count_no)

# %%
b16 = []
directory = '/home/dhruv/Projects/VidSitu/vidsitu_data/clip-vit-base-patch16'
files = os.listdir(directory)
count_yes = 0
count_no = 0
for file in files:
    with open(os.path.join(directory,file), 'rb') as f:
        try:
            data = pickle.load(f)
            count_yes += 1
        except:
            count_no += 1
            b16.append(file)
            continue
        #print(data.keys())
print('yes:', count_yes, 'no:', count_no)

# %%
# Out:
# '/home/dhruv/Projects/VidSitu/vidsitu_data/clip-vit-base-patch16'

# %%
import os

for file in l14:
    file_path = os.path.join(directory, file)
    os.remove(file_path)

# %%
print('git updated')
# Out:
# git updated

# %%
b16
# Out:
# ['v_urby-QPF1hE_seg_5_15_3',
#  'v_ZR9qd2jynNA_seg_145_155_0',
#  'v_Jipo-s5DGj8_seg_0_10_1',
#  'v_v_wQqiFXgkY_seg_55_65_0',
#  'v_r_3ofu2x8qM_seg_25_35_0',
#  'v_eSYNuO9GTU4_seg_0_10_2',
#  'v_foQnR1eZO-Y_seg_115_125_2',
#  'v_29YDqiuyaOU_seg_20_30_3',
#  'v_ZR9qd2jynNA_seg_145_155_3',
#  'v_rwr1IzFzjqA_seg_95_105_3',
#  'v_Hxtm9DG4k4o_seg_50_60_2',
#  'v_qDBjp7fdIVw_seg_110_120_3',
#  'v_iYf3nqYQXDI_seg_95_105_3',
#  'v_eSYNuO9GTU4_seg_65_75_3',
#  'v_AgLQ3qTL-t0_seg_95_105_2',
#  'v_qDBjp7fdIVw_seg_110_120_2',
#  'v_iYf3nqYQXDI_seg_95_105_1',
#  'v_Y6CMcllU8J0_seg_85_95_4',
#  'v_6vg44SEEMmA_seg_65_75_2',
#  'v_sZI5ebqgfaw_seg_30_40_1',
#  'v_GY0xXOTwWoA_seg_0_10_0',
#  'v_9jxlrFSiLCk_seg_130_140_1',
#  'v_-h62m4d4MmA_seg_30_40_3',
#  'v_r_3ofu2x8qM_seg_25_35_3',
#  'v_v_wQqiFXgkY_seg_55_65_4',
#  'v_v_wQqiFXgkY_seg_55_65_3',
#  'v_sZI5ebqgfaw_seg_30_40_0',
#  'v_6vg44SEEMmA_seg_65_75_1',
#  'v_sJsHcwZsNnI_seg_165_175_1',
#  'v_vZlWLj1-eC4_seg_30_40_1',
# ...

# %%
'v_ioE_djgs810_seg_50_60_4' in files
# Out:
# True

# %%
117245/5
# Out:
# 23449.0

# %%
117245 + 355
# Out:
# 117600

# %%
b16
# Out:
# ['v_urby-QPF1hE_seg_5_15_3',
#  'v_ZR9qd2jynNA_seg_145_155_0',
#  'v_Jipo-s5DGj8_seg_0_10_1',
#  'v_v_wQqiFXgkY_seg_55_65_0',
#  'v_r_3ofu2x8qM_seg_25_35_0',
#  'v_eSYNuO9GTU4_seg_0_10_2',
#  'v_foQnR1eZO-Y_seg_115_125_2',
#  'v_29YDqiuyaOU_seg_20_30_3',
#  'v_ZR9qd2jynNA_seg_145_155_3',
#  'v_rwr1IzFzjqA_seg_95_105_3',
#  'v_Hxtm9DG4k4o_seg_50_60_2',
#  'v_qDBjp7fdIVw_seg_110_120_3',
#  'v_iYf3nqYQXDI_seg_95_105_3',
#  'v_eSYNuO9GTU4_seg_65_75_3',
#  'v_AgLQ3qTL-t0_seg_95_105_2',
#  'v_qDBjp7fdIVw_seg_110_120_2',
#  'v_iYf3nqYQXDI_seg_95_105_1',
#  'v_Y6CMcllU8J0_seg_85_95_4',
#  'v_6vg44SEEMmA_seg_65_75_2',
#  'v_sZI5ebqgfaw_seg_30_40_1',
#  'v_GY0xXOTwWoA_seg_0_10_0',
#  'v_9jxlrFSiLCk_seg_130_140_1',
#  'v_-h62m4d4MmA_seg_30_40_3',
#  'v_r_3ofu2x8qM_seg_25_35_3',
#  'v_v_wQqiFXgkY_seg_55_65_4',
#  'v_v_wQqiFXgkY_seg_55_65_3',
#  'v_sZI5ebqgfaw_seg_30_40_0',
#  'v_6vg44SEEMmA_seg_65_75_1',
#  'v_sJsHcwZsNnI_seg_165_175_1',
#  'v_vZlWLj1-eC4_seg_30_40_1',
# ...

# %%
split = 'train'
root_dir = "/home/dhruv/Projects/VidSitu/vidsitu_data/"
split_dir = os.path.join(root_dir, "vidsitu_annotations/split_files")
split_name = os.path.join(split_dir, 'vseg_split_' + split + '_lb.json')
vids = json.load(open(split_name,'r'))

vid_trimmed_dir = os.path.join(root_dir, "vsitu_video_trimmed_dir")

anno_dir = os.path.join(root_dir, "vidsitu_annotations/vseg_ann_files")
anno_name = os.path.join(anno_dir, 'vsann_' + split + '_lb.json')
annos = json.load(open(anno_name,'r'))
annotations = []
for anno in annos:
    
    for event in anno.keys(): # should return Ev1,...,Ev5
        annotation = {}
        event_info = anno[event]
        vid_name = event_info['vid_seg_int']
        # if vid_name == 'v_JEcfknHqMyc_seg_80_90':
            # sanity check - check if video exists
        if os.path.exists(os.path.join(vid_trimmed_dir, vid_name+'.mp4')):
            annotation['vid_path'] = os.path.join(vid_trimmed_dir, vid_name+'.mp4')
            annotation['verb'] = event_info['Verb'].split()[0]
            role_dict = OrderedDict()
            args = event_info['Args']
            # Role should be Arg0, Arg1, Arg2, ArgM (location) or Scene of the Event
            for key in args.keys():
                role = key.strip(')').split('(')[-1] 
                arg_name = key.split()[0]
                if arg_name in  ['Arg0', 'Arg1', 'Arg2', 'ArgM']:
                    role_dict[role] = args[key]
                if arg_name == 'Scene':
                    role_dict[arg_name] = args[key]
            annotation['role_dict'] = role_dict
            annotation['event'] = int(event.lstrip('Ev')) -1 
            annotation['vid_seg_id'] = vid_name + '_' + str(annotation['event'])
            
            if annotation:
                annotations.append(annotation)

# %%
b16[0]
# Out:
# 'v_urby-QPF1hE_seg_5_15_3'

# %%
missing_elements = [element for element in b16 if all(element not in annotation['vid_seg_id'] for annotation in annotations)]

# %%
missing_elements
# Out:
# ['v_iYf3nqYQXDI_seg_95_105_3',
#  'v_iYf3nqYQXDI_seg_95_105_1',
#  'v_Y6CMcllU8J0_seg_85_95_4',
#  'v_iYf3nqYQXDI_seg_95_105_0',
#  'v_iYf3nqYQXDI_seg_95_105_2',
#  'v_2OXtHJgLJr0_seg_75_85_2',
#  'v_yzSfVpQ-1ns_seg_70_80_0',
#  'v_Y6CMcllU8J0_seg_85_95_3',
#  'v_sgB8cpEi_zU_seg_30_40_3',
#  'v_FAhcPXtCykY_seg_0_10_0',
#  'v_FAhcPXtCykY_seg_0_10_4',
#  'v_UYzF0CAcN3I_seg_5_15_1',
#  'v_zz0w0KDwhWg_seg_25_35_4',
#  'v_sgB8cpEi_zU_seg_30_40_2',
#  'v_FAhcPXtCykY_seg_0_10_1',
#  'v_iYf3nqYQXDI_seg_95_105_4',
#  'v_UYzF0CAcN3I_seg_5_15_4',
#  'v_2OXtHJgLJr0_seg_75_85_1',
#  'v_2OXtHJgLJr0_seg_75_85_0',
#  'v_yzSfVpQ-1ns_seg_70_80_1',
#  'v_FAhcPXtCykY_seg_0_10_2',
#  'v_yzSfVpQ-1ns_seg_70_80_2',
#  'v_UYzF0CAcN3I_seg_5_15_0',
#  'v_sgB8cpEi_zU_seg_30_40_4',
#  'v_sgB8cpEi_zU_seg_30_40_0',
#  'v_2OXtHJgLJr0_seg_75_85_3',
#  'v_UYzF0CAcN3I_seg_5_15_3',
#  'v_zz0w0KDwhWg_seg_25_35_0',
#  'v_yzSfVpQ-1ns_seg_70_80_4',
#  'v_UYzF0CAcN3I_seg_5_15_2',
#  'v_zz0w0KDwhWg_seg_25_35_3',
# ...

# %%
found_annotations = [x for x in annotations if 'v_M3u94uEBq9o_seg_80_90' in x['vid_seg_id']]

# %%
found_annotations
# Out:
# [{'vid_path': '/home/dhruv/Projects/VidSitu/vidsitu_data/vsitu_video_trimmed_dir/v_M3u94uEBq9o_seg_80_90.mp4',
#   'verb': 'dive',
#   'role_dict': OrderedDict([('thing falling', 'man in wetsuit'),
#                ('direction', 'downward'),
#                ('Scene', 'lake')]),
#   'event': 0,
#   'vid_seg_id': 'v_M3u94uEBq9o_seg_80_90_0'},
#  {'vid_path': '/home/dhruv/Projects/VidSitu/vidsitu_data/vsitu_video_trimmed_dir/v_M3u94uEBq9o_seg_80_90.mp4',
#   'verb': 'breathe',
#   'role_dict': OrderedDict([('breather', 'man in wetsuit'),
#                ('air, we hope', 'man in wetsuit'),
#                ('manner', 'aggressively'),
#                ('Scene', 'lake')]),
#   'event': 1,
#   'vid_seg_id': 'v_M3u94uEBq9o_seg_80_90_1'},
#  {'vid_path': '/home/dhruv/Projects/VidSitu/vidsitu_data/vsitu_video_trimmed_dir/v_M3u94uEBq9o_seg_80_90.mp4',
#   'verb': 'talk',
#   'role_dict': OrderedDict([('talker', 'brunette girl'),
#                ('hearer', 'brunette boy'),
# ...

# %%
b16[0] in annotations
# Out:
# False

# %%
annotations[0]
# Out:
# {'vid_path': '/home/dhruv/Projects/VidSitu/vidsitu_data/vsitu_video_trimmed_dir/v_M3u94uEBq9o_seg_80_90.mp4',
#  'verb': 'dive',
#  'role_dict': OrderedDict([('thing falling', 'man in wetsuit'),
#               ('direction', 'downward'),
#               ('Scene', 'lake')]),
#  'event': 0,
#  'vid_seg_id': 'v_M3u94uEBq9o_seg_80_90_0'}
